# %%
# !pip install transformers trl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 30.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 39.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 22.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.9 MB/s eta 0:00:00
# ...

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("yankihue/final-gpt2-tr-positive-sentiment-tweets-final")

model = AutoModelForCausalLM.from_pretrained("yankihue/final-gpt2-tr-positive-sentiment-tweets-final")

tokenizer.eos_token_id = model.config.eos_token_id
tokenizer.pad_token = tokenizer.eos_token
# Out:
# ...
# Some weights of the model checkpoint at yankihue/h-rlhf-final-gpt2-tr-positive-sentiment-tweets-final were not used when initializing GPT2LMHeadModel: ['v_head.summary.weight', 'v_head.summary.bias']
# - This IS expected if you are initializing GPT2LMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing GPT2LMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("yankihue/tweets-turkish",split="train")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/yankihue___csv/yankihue--tweets-turkish-c9963a0770919f45/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.

# %%
import pandas as pd

# %%
dataset
# Out:
# Dataset({
#     features: ['Paylaşım', 'Tip'],
#     num_rows: 11108
# })

# %%
df = dataset.to_pandas()

# %%
df
# Out:
#                                                 Paylaşım      Tip
# 0                          Doğa ağzımıza sıçsa hakkı var  Negatif
# 1      Anne bir sanatçıdır, en güzel eseri de yavrusu...  Pozitif
# 2       ibrahimin oğlunu koruyan Tanrıya da ben sokayım  Negatif
# 3            Köpeğim suratına sıçsın senin namussuz karı  Negatif
# 4                    Ben söğüşledim, birazda sen söğüşle  Negatif
# ...                                                  ...      ...
# 11103  eğer gidip bir aynaya bakarsanız orada en büyü...  Negatif
# 11104                           Asıl fahişe senin beynin  Negatif
# 11105     Sorsak bir numaralı müslümandır sıfatsız herif  Negatif
# 11106                          surata bak lenetlenmiş oç  Negatif
# 11107  Allah ın din tüccarları sizi. Bir insana ifti...  Negatif
#
# [11108 rows x 2 columns]

# %%
df_pos = df[df['Tip'] == "Pozitif"]

# %%
df_pos
# Out:
#                                                 Paylaşım      Tip
# 1      Anne bir sanatçıdır, en güzel eseri de yavrusu...  Pozitif
# 8      En uzun yolculuklar bile, tek bir adımla başla...  Pozitif
# 9            Vallahi bu aralar istediğimiz tek şey huzur  Pozitif
# 10     CHP Genel Başkanı Kemal Kılıçdaroğlu'nun eşi S...  Pozitif
# 11     Beyin göçünü engellemeye çalıştığımız gençlere...  Pozitif
# ...                                                  ...      ...
# 11081  Mentoronoma iki drum vuram da birbirine benzey...  Pozitif
# 11082  dur bi btsin su mvsinden de koyam yok bu az ge...  Pozitif
# 11084             şekeri dedim bari bayram şekeri koyam   Pozitif
# 11091   SoruSorarim Gülüm ne ediyon gali geh otur çay...  Pozitif
# 11092                                 çay koyayım içelim  Pozitif
#
# [6109 rows x 2 columns]

# %%
df_sampled = df_pos.sample(n=3000)

# %%
df_sampled
# Out:
#                                                 Paylaşım      Tip
# 6417   Onlar hiç hafiflemeyen bir azabın içinde kalsı...  Pozitif
# 9320   Cinsel kimlik medya aracılığıyla şekillenen bi...  Pozitif
# 2435   Aslında ufak çaplı sezaiye bi laf sokuş haberi...  Pozitif
# 912                        Gündemdeki sıcak gelişmelerle  Pozitif
# 9779    Kadına çocuğa yetime güçsüze bu kadar şiddett...  Pozitif
# ...                                                  ...      ...
# 919    Cumhurbaşkanı Erdoğan, Türkiye-Rusya-İran Üçlü...  Pozitif
# 10651   Kimin kabini kırdım ise isterse kafir olsun ö...  Pozitif
# 3867   bazı insanlar şükür sebebi olabiliyorlar sen e...  Pozitif
# 7577    yıl önce yaptığı dans yüzünden tribünden atıl...  Pozitif
# 5113   kadınallahınemanetidir kutlu davanın yıkılmaz ...  Pozitif
#
# [3000 rows x 2 columns]

# %%
import numpy as np

# %%
def random_substring(s):
    if len(s) <= 10:
        return s
    elif 10 < len(s) < 40:
        end = np.random.randint(10, len(s))
        return s[:end]
    else:
        end = np.random.randint(10, 41)
        return s[:end]

# %%
df_sampled['paylaşım_substring'] = df_sampled['Paylaşım'].apply(random_substring)

# %%
from transformers import pipeline

# %%
import torch

# %%
outputs = list()

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %%
from trl.core import LengthSampler

output_min_length = 4
output_max_length = 16
output_length_sampler = LengthSampler(output_min_length, output_max_length)

gen_len=output_length_sampler()

# %%
for i in range(3000):
  input_text = df_sampled.iloc[i]['paylaşım_substring']
  input_ids = tokenizer.encode(input_text, return_tensors='pt')

  # generate output from the model
  output = model.generate(input_ids,max_new_tokens=gen_len, **gen_kwargs)

  decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)
  outputs.append(decoded_output)

# %%
df2 = pd.DataFrame({"query": df_sampled['paylaşım_substring'], "output": outputs },columns=["query","output"])

# %%
df2
# Out:
#                                    query  \
# 6417                    Onlar hiç hafifl
# 9320   Cinsel kimlik medya aracılığıyla
# 2435           Aslında ufak çaplı sezaiy
# 912                           Gündemdeki
# 9779        Kadına çocuğa yetime güçsüze
# ...                                  ...
# 919                  Cumhurbaşkanı Erdoğ
# 10651           Kimin kabini kırdım ise
# 3867                        bazı insanla
# 7577      yıl önce yaptığı dans yüzünden
# 5113                kadınallahınemanetid
#
#                                                   output
# 6417   Onlar hiç hafifl! Yine harika! Sizi mükemmel! ...
# 9320   Cinsel kimlik medya aracılığıyla  güzel herkes...
# 2435   Aslında ufak çaplı sezaiy:) Özel Rock, en güze...
# 912    Gündemdeki tüm bir çok, mineral, dünya güzeli, de
# 9779    Kadına çocuğa yetime güçsüze bu... İşte gerçe...
# ...                                                  ...
# 919    Cumhurbaşkanı Erdoğ...\nO muhteşem, bir insan ...
# ...

# %%
df2['output'] = df2.apply(lambda row: row['output'].replace(row['query'], ''), axis=1)

# %%
df2.to_csv("pozitif tweet rlhf 3k final.csv",index = False)

# %%
df2
# Out:
#                                    query  \
# 6417                    Onlar hiç hafifl
# 9320   Cinsel kimlik medya aracılığıyla
# 2435           Aslında ufak çaplı sezaiy
# 912                           Gündemdeki
# 9779        Kadına çocuğa yetime güçsüze
# ...                                  ...
# 919                  Cumhurbaşkanı Erdoğ
# 10651           Kimin kabini kırdım ise
# 3867                        bazı insanla
# 7577      yıl önce yaptığı dans yüzünden
# 5113                kadınallahınemanetid
#
#                                                   output
# 6417         ! Yine harika! Sizi mükemmel! Unutulmaz bir
# 9320    güzel herkesin! Tüm grafikleri ile en iyi bir...
# 2435   :) Özel Rock, en güzel oldukça orjinal, gerçekten
# 912               tüm bir çok, mineral, dünya güzeli, de
# 9779    bu... İşte gerçekten pek güzel çok ruhu ve ge...
# ...                                                  ...
# 919             ...\nO muhteşem, bir insan için en güzel
# ...
