# %%
import pandas as pd

# Read data from a file (e.g., CSV file) into a DataFrame
data = pd.read_csv('unranked_outputs_full_positive_hack.csv')

# Add a new column with the name "marked" and assign all rows the value of 0
data['marked'] = 0

# Save the modified DataFrame to a new file
data.to_csv('unranked_outputs_unmarked.csv', index=False)
